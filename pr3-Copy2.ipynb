# %% [markdown]
# # Standard scaler - dataset 1000개로 줄여서, epoch 30으로 돌려보기

# %%
import pandas as pd
standard_1000 = pd.read_csv('C:/Users/coco7/OneDrive/바탕화면/제형설계 참조 파일/실험실/data/p4_standard_scaled.csv')

# %%
standard_1000
# Out:
#       Unnamed: 0                             smiles  Molecular Weight  \
# 0              0                                 BB         -1.521793
# 1              1                      BrC(Br)(Br)Br          0.213386
# 2              2        BrC(Br)\C(Br)=C(Br)\C(Br)Br          1.342828
# 3              3  BrC(c1ccccc1)=C(c2ccccc2)c3ccccc3          0.233994
# 4              4                  BrC1=CNC(=O)NC1=O         -0.589525
# ...          ...                                ...               ...
# 7482        7482                           c1cncnc1         -1.222550
# 7483        7483    o1c(c2ccccc2)c3ccccc3c1c4ccccc4         -0.136607
# 7484        7484                            o1cccn1         -1.285515
# 7485        7485                      o1cnc2ccccc12         -0.999744
# 7486        7486                      s1ccc2ccccc12         -0.913658
#
#           logP       pKa  Mass Solubility pH 1  Mass Solubility pH 2  \
# ...

# %%
standard_1000=standard_1000[:1000]

# %%
standard_1000.to_csv('C:/Users/coco7/OneDrive/바탕화면/제형설계 참조 파일/실험실/data/standard_1000.csv')

# %%
# %cd C:/Users/coco7/chemprop
# %run train.py --data_path C:/Users/coco7/OneDrive/바탕화면/"제형설계 참조 파일"/실험실/data/standard_1000.csv --dataset_type regression --save_dir C:/Users/coco7/OneDrive/바탕화면/"제형설계 참조 파일"/실험실/data/pr4_scaled --smiles_column smiles --epoch 30
# Out:
# C:\Users\coco7\chemprop
# WARNING:root:No normalization for BCUT2D_MWHI
# WARNING:root:No normalization for BCUT2D_MWLOW
# WARNING:root:No normalization for BCUT2D_CHGHI
# WARNING:root:No normalization for BCUT2D_CHGLO
# WARNING:root:No normalization for BCUT2D_LOGPHI
# WARNING:root:No normalization for BCUT2D_LOGPLOW
# WARNING:root:No normalization for BCUT2D_MRHI
# WARNING:root:No normalization for BCUT2D_MRLOW
# Command line
# python train.py --data_path C:/Users/coco7/OneDrive/바탕화면/제형설계 참조 파일/실험실/data/standard_1000.csv --dataset_type regression --save_dir C:/Users/coco7/OneDrive/바탕화면/제형설계 참조 파일/실험실/data/pr4_scaled --smiles_column smiles --epoch 30
# Args
# {'activation': 'ReLU',
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'alternative_loss_function': None,
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'batch_size': 50,
# ...

# %% [markdown]
# ### dropout 추가

# %%
# %cd C:/Users/coco7/chemprop
# %run train.py --data_path C:/Users/coco7/OneDrive/바탕화면/"제형설계 참조 파일"/실험실/data/standard_1000.csv --dataset_type regression --save_dir C:/Users/coco7/OneDrive/바탕화면/"제형설계 참조 파일"/실험실/data/pr4_scaled --smiles_column smiles --epoch 30 --dropout 0.2
# Out:
# Command line
# python train.py --data_path C:/Users/coco7/OneDrive/바탕화면/제형설계 참조 파일/실험실/data/standard_1000.csv --dataset_type regression --save_dir C:/Users/coco7/OneDrive/바탕화면/제형설계 참조 파일/실험실/data/pr4_scaled --smiles_column smiles --epoch 30 --dropout 0.2
# Args
# {'activation': 'ReLU',
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'alternative_loss_function': None,
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'batch_size': 50,
#  'bias': False,
#  'bond_feature_scaling': True,
#  'bond_features_path': None,
#  'bond_features_size': 0,
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': True,
# ...

# %% [markdown]
# # min max scaled 1000개 + epoch 30 + dropout 0.2

# %%
import pandas as pd
minmax1000 = pd.read_csv('C:/Users/coco7/OneDrive/바탕화면/제형설계 참조 파일/실험실/data/p4_minmax_scaled.csv')
minmax1000
# Out:
#       Unnamed: 0                             smiles  Molecular Weight  \
# 0              0                                 BB          0.008750
# 1              1                      BrC(Br)(Br)Br          0.112440
# 2              2        BrC(Br)\C(Br)=C(Br)\C(Br)Br          0.179933
# 3              3  BrC(c1ccccc1)=C(c2ccccc2)c3ccccc3          0.113672
# 4              4                  BrC1=CNC(=O)NC1=O          0.064460
# ...          ...                                ...               ...
# 7482        7482                           c1cncnc1          0.026632
# 7483        7483    o1c(c2ccccc2)c3ccccc3c1c4ccccc4          0.091526
# 7484        7484                            o1cccn1          0.022869
# 7485        7485                      o1cnc2ccccc12          0.039947
# 7486        7486                      s1ccc2ccccc12          0.045091
#
#           logP       pKa  Mass Solubility pH 1  Mass Solubility pH 2  \
# ...

# %%
minmax1000 = minmax1000[:1000]
minmax1000
# Out:
#      Unnamed: 0                                             smiles  \
# 0             0                                                 BB
# 1             1                                      BrC(Br)(Br)Br
# 2             2                        BrC(Br)\C(Br)=C(Br)\C(Br)Br
# 3             3                  BrC(c1ccccc1)=C(c2ccccc2)c3ccccc3
# 4             4                                  BrC1=CNC(=O)NC1=O
# ..          ...                                                ...
# 995         995   CC/C(c1ccccc1)=C(/c2ccc(OCCN(C)C)cc2)c3cccc(O)c3
# 996         996  CC/C(c1ccccc1)=C(c2ccc(I)cc2)/c3ccc(OCCN4CCCC4...
# 997         997      CC/C(c1ccccc1)=C(c2ccccc2)/c3ccc(OCCN(C)C)cc3
# 998         998  CC/C(c1ccccc1)=C(c2ccccc2)/c3ccc(OCCN(C)C)cc3....
# 999         999           CC/C=C\C\C=C/C/C=C\C\C=C/C/C=C\CCCC(O)=O
#
#      Molecular Weight      logP       pKa  Mass Solubility pH 1  \
# 0            0.008750       NaN       NaN                   NaN
# ...

# %%
minmax1000.to_csv('C:/Users/coco7/OneDrive/바탕화면/제형설계 참조 파일/실험실/data/p4_minmax_1000.csv')

# %%
# %cd C:/Users/coco7/chemprop
# %run train.py --data_path C:/Users/coco7/OneDrive/바탕화면/"제형설계 참조 파일"/실험실/data/p4_minmax_1000.csv --dataset_type regression --save_dir C:/Users/coco7/OneDrive/바탕화면/"제형설계 참조 파일"/실험실/data/pr4_minmax_1000 --smiles_column smiles --epoch 30 --dropout 0.2
# Out:
# C:\Users\coco7\chemprop
# WARNING:root:No normalization for BCUT2D_MWHI
# WARNING:root:No normalization for BCUT2D_MWLOW
# WARNING:root:No normalization for BCUT2D_CHGHI
# WARNING:root:No normalization for BCUT2D_CHGLO
# WARNING:root:No normalization for BCUT2D_LOGPHI
# WARNING:root:No normalization for BCUT2D_LOGPLOW
# WARNING:root:No normalization for BCUT2D_MRHI
# WARNING:root:No normalization for BCUT2D_MRLOW
# Command line
# python train.py --data_path C:/Users/coco7/OneDrive/바탕화면/제형설계 참조 파일/실험실/data/p4_minmax_1000.csv --dataset_type regression --save_dir C:/Users/coco7/OneDrive/바탕화면/제형설계 참조 파일/실험실/data/pr4_minmax_1000 --smiles_column smiles --epoch 30 --dropout 0.2
# Args
# {'activation': 'ReLU',
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'alternative_loss_function': None,
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
# ...
